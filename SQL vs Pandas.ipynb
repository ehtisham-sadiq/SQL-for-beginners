# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("Student_Records_202206231920.csv")
df
# Out:
#    Student_Id First_Name     Address  Age  Percentage Grade
# 0           5      Fajar     Sahiwal   20          75    B1
# 1         201   Ehtisham       Okara   18          89    A2
# 2         202        Ali      Lahore   19          93    A1
# 3         203      Fizaa       Okara   20          89    A2
# 4         204      Ahmed      Lahore   19          78    B1
# 5         206     Multan      Salman   19          51    C1
# 6         207       Azka  Rawalpandi   20          62    B2

# %%
df['Grade'].value_counts()
# Out:
# B1    2
# A2    2
# A1    1
# C1    1
# B2    1
# Name: Grade, dtype: int64

# %%
df.describe()
# Out:
#        Student_Id        Age  Percentage
# count    7.000000   7.000000    7.000000
# mean   175.428571  19.285714   76.714286
# std     75.181685   0.755929   15.542568
# min      5.000000  18.000000   51.000000
# 25%    201.500000  19.000000   68.500000
# 50%    203.000000  19.000000   78.000000
# 75%    205.000000  20.000000   89.000000
# max    207.000000  20.000000   93.000000

# %%
df[df['Address'] =='Lahore']
# Out:
#    Student_Id First_Name Address  Age  Percentage Grade
# 2         202        Ali  Lahore   19          93    A1
# 4         204      Ahmed  Lahore   19          78    B1

# %%
df['Address'].value_counts()
# Out:
# Okara         2
# Lahore        2
# Sahiwal       1
# Salman        1
# Rawalpandi    1
# Name: Address, dtype: int64

# %%
# sns.countplot(df['Address'])

# %% [markdown]
# #### Ordered By or Sorting

# %%
df.sort_values('Percentage', ascending=True)
# Out:
#    Student_Id First_Name     Address  Age  Percentage Grade
# 5         206     Multan      Salman   19          51    C1
# 6         207       Azka  Rawalpandi   20          62    B2
# 0           5      Fajar     Sahiwal   20          75    B1
# 4         204      Ahmed      Lahore   19          78    B1
# 1         201   Ehtisham       Okara   18          89    A2
# 3         203      Fizaa       Okara   20          89    A2
# 2         202        Ali      Lahore   19          93    A1

# %% [markdown]
# #### Unique Method

# %%
df[['Age','Grade']].unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
# ----> 1 df[['Age','Grade']].unique()
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'unique'

# %%
# !ls
# Out:
#  images					     'SQL vs Pandas.ipynb'
# 'Introduction to SQL.ipynb'		      Student_Records_202206231920.csv
#  README.md				      world-university-rankings-202223
# 'SQL interview Questions and Answers.ipynb'

# %%
# !ls world-university-rankings-202223
# Out:
# 2023_QS_World_University_Rankings.csv

# %%
path = "world-university-rankings-202223/2023_QS_World_University_Rankings.csv"
df2 = pd.read_csv(path)

# %%
df2.head()
# Out:
#    Rank                                   institution location code  \
# 0     1  Massachusetts Institute of Technology (MIT)             US
# 1     2                       University of Cambridge            UK
# 2     3                           Stanford University            US
# 3     4                          University of Oxford            UK
# 4     5                            Harvard University            US
#
#          location  ar score ar rank  er score er rank  fsr score fsr rank  \
# 0   United States     100.0       5     100.0       4      100.0       14
# 1  United Kingdom     100.0       2     100.0       2      100.0       11
# 2   United States     100.0       4     100.0       5      100.0        6
# 3  United Kingdom     100.0       3     100.0       3      100.0        8
# 4   United States     100.0       1     100.0       1       99.4       35
#
#    ...  cpf rank ifr score  ifr rank isr score  isr rank irn score  irn rank  \
# ...

# %%
df2.isnull().sum()
# Out:
# Rank              0
# institution       0
# location code     0
# location          0
# ar score          0
# ar rank           0
# er score          1
# er rank           0
# fsr score         2
# fsr rank          0
# cpf score         5
# cpf rank          0
# ifr score        98
# ifr rank         98
# isr score        57
# isr rank         57
# irn score        13
# irn rank         13
# ger score        12
# ger rank         12
# score scaled      0
# dtype: int64

# %%
df2.columns
# Out:
# Index(['Rank', 'institution', 'location code', 'location', 'ar score',
#        'ar rank', 'er score', 'er rank', 'fsr score', 'fsr rank', 'cpf score',
#        'cpf rank', 'ifr score', 'ifr rank', 'isr score', 'isr rank',
#        'irn score', 'irn rank', 'ger score', 'ger rank', 'score scaled'],
#       dtype='object')

# %%
df2[(df2['location code'] =="PK" ) & (df2['Rank']<1000)]
# Out:
#      Rank                                        institution location code  \
# 333   334  National University of Sciences And Technology...            PK
# 364   365                            Quaid-i-Azam University            PK
# 389   390  Pakistan Institute of Engineering and Applied ...            PK
# 614   615    Lahore University of Management Sciences (LUMS)            PK
# 962   963  University of Engineering & Technology (UET) L...            PK
# 985   986                             University of Peshawar            PK
# 989   990                           University of the Punjab            PK
#
#      location  ar score ar rank  er score er rank  fsr score fsr rank  ...  \
# 333  Pakistan      18.2     474      67.7     104       77.0      154  ...
# 364  Pakistan      15.4    501+      38.4     245        2.6     601+  ...
# 389  Pakistan       5.2    501+       8.2    501+       86.4      104  ...
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1422 entries, 0 to 1421
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Rank           1422 non-null   int64
#  1   institution    1422 non-null   object
#  2   location code  1422 non-null   object
#  3   location       1422 non-null   object
#  4   ar score       1422 non-null   float64
#  5   ar rank        1422 non-null   object
#  6   er score       1421 non-null   float64
#  7   er rank        1422 non-null   object
#  8   fsr score      1420 non-null   float64
#  9   fsr rank       1422 non-null   object
#  10  cpf score      1417 non-null   float64
#  11  cpf rank       1422 non-null   object
#  12  ifr score      1324 non-null   float64
#  13  ifr rank       1324 non-null   object
#  14  isr score      1365 non-null   float64
#  15  isr rank       1365 non-null   object
#  16  irn score      1409 non-null   float64
# ...

# %%
df2.shape
# Out:
# (1422, 21)

# %%
import pandas as pd

# %%
df3 = pd.read_csv("datasets/suicide-rates-overview-1985-to-2016.csv")
df3.head()
# Out:
#    country  year     sex          age  suicides_no  population  \
# 0  Albania  1987    male  15-24 years           21      312900
# 1  Albania  1987    male  35-54 years           16      308000
# 2  Albania  1987  female  15-24 years           14      289700
# 3  Albania  1987    male    75+ years            1       21800
# 4  Albania  1987    male  25-34 years            9      274300
#
#    suicides/100k pop country-year  HDI for year  gdp_for_year ($)   \
# 0               6.71  Albania1987           NaN      2,156,624,900
# 1               5.19  Albania1987           NaN      2,156,624,900
# 2               4.83  Albania1987           NaN      2,156,624,900
# 3               4.59  Albania1987           NaN      2,156,624,900
# 4               3.28  Albania1987           NaN      2,156,624,900
#
#    gdp_per_capita ($)       generation
# 0                 796     Generation X
# 1                 796           Silent
# 2                 796     Generation X
# ...

# %%
df3.shape
# Out:
# (27820, 12)

# %%
df3_New = df3[(df3['country'] == "Albania")]
sns.countplot(df3_New['generation'])
# df3_New['generation'].value_counts()
# Out:
# /home/dell/.local/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='generation', ylabel='count'>

# %%
df3.isnull().sum()
# Out:
# country               0
# year                  0
# sex                   0
# age                   0
# suicides_no           0
# population            0
# suicides/100k pop     0
# country-year          0
#  gdp_for_year ($)     0
# gdp_per_capita ($)    0
# generation            0
# dtype: int64

# %%
df3.drop(['HDI for year'], axis=1, inplace=True)

# %%
df3.sample(10)
# Out:
#                    country  year     sex          age  suicides_no  \
# 3185              Barbados  2013    male   5-14 years            0
# 15839                Malta  1987  female  55-74 years            0
# 384    Antigua and Barbuda  1995  female  15-24 years            0
# 22713            Singapore  2011    male  55-74 years           68
# 26738       United Kingdom  2006    male   5-14 years            4
# 18568             Paraguay  1985  female  15-24 years            9
# 6446               Croatia  2001    male  15-24 years           55
# 18904          Philippines  1993  female    75+ years           10
# 27501              Uruguay  2010  female  55-74 years           42
# 1988               Austria  2001  female   5-14 years            1
#
#        population  suicides/100k pop             country-year  HDI for year  \
# 3185        19376               0.00             Barbados2013         0.785
# ...
